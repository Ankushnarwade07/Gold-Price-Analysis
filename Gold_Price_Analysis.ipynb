# %% [markdown]
# ## **Gold Price Analysis of India (2018-2023)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
data = pd.read_csv('/content/Gold.csv')

# %%
data.head()
# Out:
#         Date    Open    High     Low   Close  Adj Close  Volume
# 0  3/29/2023  1966.1  1966.1  1966.1  1966.1     1966.1    21.0
# 1  3/28/2023  1972.4  1972.4  1972.4  1972.4     1972.4    21.0
# 2  3/27/2023  1957.2  1957.2  1952.4  1952.4     1952.4   877.0
# 3  3/24/2023  1991.7  1995.4  1982.1  1982.1     1982.1    19.0
# 4  3/23/2023  1990.5  1994.6  1990.5  1993.8     1993.8    33.0

# %%
data = pd.read_csv('/content/Gold.csv', index_col="Date", parse_dates=True)
data
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2023-03-29  1966.1  1966.1  1966.1  1966.1     1966.1    21.0
# 2023-03-28  1972.4  1972.4  1972.4  1972.4     1972.4    21.0
# 2023-03-27  1957.2  1957.2  1952.4  1952.4     1952.4   877.0
# 2023-03-24  1991.7  1995.4  1982.1  1982.1     1982.1    19.0
# 2023-03-23  1990.5  1994.6  1990.5  1993.8     1993.8    33.0
# ...            ...     ...     ...     ...        ...     ...
# 2018-04-06  1326.5  1333.0  1319.0  1331.9     1331.9   348.0
# 2018-04-05  1333.5  1333.7  1322.6  1324.3     1324.3   258.0
# 2018-04-04  1331.8  1347.3  1331.6  1335.8     1335.8   718.0
# 2018-04-03  1340.4  1341.5  1328.5  1332.8     1332.8   702.0
# 2018-04-02  1327.0  1344.2  1324.7  1342.1     1342.1   649.0
#
# [1232 rows x 6 columns]

# %%
data.tail()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2018-04-06  1326.5  1333.0  1319.0  1331.9     1331.9   348.0
# 2018-04-05  1333.5  1333.7  1322.6  1324.3     1324.3   258.0
# 2018-04-04  1331.8  1347.3  1331.6  1335.8     1335.8   718.0
# 2018-04-03  1340.4  1341.5  1328.5  1332.8     1332.8   702.0
# 2018-04-02  1327.0  1344.2  1324.7  1342.1     1342.1   649.0

# %%
data.shape
# Out:
# (1232, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1232 entries, 2023-03-29 to 2018-04-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1232 non-null   float64
#  1   High       1232 non-null   float64
#  2   Low        1232 non-null   float64
#  3   Close      1232 non-null   float64
#  4   Adj Close  1232 non-null   float64
#  5   Volume     1232 non-null   float64
# dtypes: float64(6)
# memory usage: 67.4 KB

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean   1641.484253  1649.514854  1633.614042  1641.593669  1641.593669
# std     241.508320   243.943833   239.243489   241.587355   241.587355
# min    1173.200000  1180.200000  1161.400000  1176.200000  1176.200000
# 25%    1429.825000  1440.450000  1422.625000  1425.900000  1425.900000
# 50%    1735.650000  1744.450000  1725.800000  1734.400000  1734.400000
# 75%    1829.325000  1838.700000  1820.825000  1830.950000  1830.950000
# max    2053.600000  2072.000000  2040.000000  2051.500000  2051.500000
#
#               Volume
# count    1232.000000
# mean     5167.344968
# std     29470.940551
# min         1.000000
# 25%        56.000000
# 50%       209.500000
# 75%       612.250000
# max    386334.000000

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['Open'], color='r')
plt.grid(True)

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['High'], color='r')
plt.grid(True)

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['Low'], color='r')
plt.grid(True)

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['Close'], color='r')
plt.grid(True)

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['Adj Close'], color='r')
plt.grid(True)

# %%
plt.figure(figsize=(10,7))
#sns.lineplot(data=df)
x = plt.xticks(rotation=90)
sns.lineplot(data=data['Volume'], color='r')
plt.grid(True)

# %% [markdown]
# **Conclusion:**
# # **The Analysis Gold Price in India is done successfully...**
